# %%
# %%markdown
# #  **WEEK 7: Student Management System**
# # *Name: Motiba*
# This project uses a class to add, update, and view student records.
# Out:
# #  **WEEK 7: Student Management System**
# # *Name: Motiba*
# This project uses a class to add, update, and view student records.

# %%
student = {
    "id":"101",
    "name":"Ali",
    "age":"20",
    "course":"python"
}

# %%
class StudentManagementSystem:
    #constructor
    def __init__(self):
        self.students = []

    #Add a new student
    def add_student(self):
        print("===== ADD STUDENT =====")

        student_id = input("Enter Student ID: ").strip()
        name = input("Enter Student name: ").strip().title()
        age = input("Enter Student age: ").strip()
        course = input("Enter student course: ").strip().title()

        #Check empty information
        if (student_id == "" or name == "" or age == "" or course == ""):
            print("All information is required.")
            return

        #Check duplicate Student ID
        for student in self.students:
            if student["id"] == student_id:
                print("This student ID is already exist.")
                return

        #Create one student record
        student = {
            "id": student_id,
            "name": name,
            "age": age,
            "course": course
        }
        self.students.append(student)
        print("Student added successfully.")

    #Update a existing Student
    def update_student(self):
        print("======= UPDATE STUDENT =======")

        if len(self.students) == 0:
            print("No student records are available.")
            return
        student_id = input("Enter student ID to update: ").strip()

        for student in self.students:
            if student ["id"] == student_id:
                print("Student found: " , student["name"])
                
                new_name = input("Enter new name: ").strip().title()
                new_age = input("Enter new age: ").strip()
                new_course = input("Enter new course: ").strip().title

                if (new_name == "" or new_age == "" or new_course == ""):
                    print("New information cannot be empty.")
                    return

                student["name"] = new_name
                student["age"] = new_age
                student["course"] = new_course

                print("Student updated successfully.")
                return
        print("Student ID eas not found.")

    #Display all students
    def view_students(self):
        print("====== ALL STUDENTS ======")

        if len(self.students) == 0:
            print("No Student records are available.")
            return

        for student in self.students:
            print("Student ID", student["id"])
            print("Name:", student["name"])
            print("Age:", student["age"] )
            print("Course:", student["course"])

# %%
# %%markdown
# #  **Create the Object and Run the Student Menu**
# Out:
# #  **Create the Object and Run the Student Menu**

# %%
#Create an Object of the Class
system = StudentManagementSystem()

#Main Menu
while True:
    print("======== STUDENT MANAGEMENT SYSTEM ========")
    print("1. Add Student")
    print("2. Update Student")
    print("3. View All Students")
    print("4. Exit")

    choice = input("Enter your Choice: ").strip()

    if choice == "1":
        system.add_student()

    elif choice == "2":
        system.update_student()

    elif choice == "3":
        system.view_students()

    elif choice == "4":
        print("Student Management System is Closed.")
        break

    else:
        print("Invalid choice. Enter 1, 2, 3, or 4." )
# Out:
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  1
# ===== ADD STUDENT =====
# Enter Student ID:  101
# Enter Student name:  Ali
# Enter Student age:  20
# Enter student course:  Python
# Student added successfully.
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  1
# ===== ADD STUDENT =====
# Enter Student ID:  102
# Enter Student name:  Sara
# Enter Student age:  19
# Enter student course:  Cyber security
# Student added successfully.
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  1
# ===== ADD STUDENT =====
# Enter Student ID:  103
# Enter Student name:  Ahmed
# Enter Student age:  21
# Enter student course:  Statistics
# Student added successfully.
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  2
# ======= UPDATE STUDENT =======
# Enter student ID to update:  103
# Student found:  Ahmed
# Enter new name:  Ahmed
# Enter new age:  21
# Enter new course:  Data Science
# Student updated successfully.
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  2
# ======= UPDATE STUDENT =======
# Enter student ID to update:  12
# Student ID eas not found.
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  3
# ====== ALL STUDENTS ======
# Student ID 101
# Name: Ali
# Age: 20
# Course: Python
# Student ID 102
# Name: Sara
# Age: 19
# Course: Cyber Security
# Student ID 103
# Name: Ahmed
# Age: 21
# Course: <built-in method title of str object at 0x000001FF60A937F0>
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  5
# Invalid choice. Enter 1, 2, 3, or 4.
# ======== STUDENT MANAGEMENT SYSTEM ========
# 1. Add Student
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter your Choice:  4
# Student Management System is Closed.
